# %% [markdown]
# # End-to-end music-context demo
# Run `python scripts/make_synthetic_data.py --count 24`, train Task 3, then inspect `results/fusion_case_studies.json`. Replace the synthetic manifest with your processed FMA/GTZAN metadata for final experiments.

# %%
# !python -m src.train --task fusion --synthetic --epochs 2
# !python -m src.evaluate --checkpoint results/fusion_best.pt --task fusion
